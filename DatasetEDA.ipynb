# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/purva/anaconda3/bin/notebookProject/csv/dataset1.csv")
df.head()
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %% [markdown]
# # basic commands

# %%
df.shape
# Out:
# (3510, 21)

# %% [markdown]
# ### group by

# %%
df.groupby('city')['city'].count().sort_values(ascending=False)[0:10]
# Out:
# city
# Philadelphia         91
# New York             88
# Charleston           73
# Los Angeles          60
# East Granby          55
# Columbus             41
# Weirton              32
# Clifton Park         31
# White Plains         29
# Lawrence Township    28
# Name: city, dtype: int64

# %%
#another way of doing this is value count
df['city'].value_counts()
# Out:
# Philadelphia         91
# New York             88
# Charleston           73
# Los Angeles          60
# East Granby          55
# Columbus             41
# Weirton              32
# Clifton Park         31
# White Plains         29
# Lawrence Township    28
# Rockville            25
# Pittsburgh           24
# Vernon Rockville     24
# Denver               23
# Houston              23
# Louisville           22
# Indianapolis         22
# Phoenix              22
# Middletown           21
# Rochester            20
# Greensboro           20
# Wyckoff              20
# Bartow               20
# Cockeysville         20
# Fairfield            19
# Ocala                19
# Colorado Springs     18
# Weehawken            18
# Lake Forest          18
# Arcadia              18
#                      ..
# Crown Point           1
# Whitestone            1
# South Portland        1
# Skillman              1
# North Andover         1
# Fremont               1
# Harvey                1
# ...

# %% [markdown]
# ### getting all the column names

# %%
df.columns
# Out:
# Index(['id', 'address', 'categories', 'city', 'country', 'keys', 'latitude',
#        'longitude', 'menuPageURL', 'menus.amountMax', 'menus.amountMin',
#        'menus.currency', 'menus.dateSeen', 'menus.description', 'menus.name',
#        'name', 'postalCode', 'priceRangeCurrency', 'priceRangeMin',
#        'priceRangeMax', 'province'],
#       dtype='object')

# %% [markdown]
# ### knowing statistics

# %%
print(df['menus.amountMax'].min())
print(df['menus.amountMax'].max())
print(df['menus.amountMax'].mean())
print(df['menus.amountMax'].std())
# Out:
# 0.0
# 312.95
# 12.479185888738241
# 13.398923102022168

# %%
# another better way of doing this is describe()...it excludes NaN values
df.describe()
# Out:
#           latitude    longitude  menus.amountMax  menus.amountMin  \
# count  3510.000000  3510.000000      2948.000000      2948.000000
# mean     38.555114   -87.472055        12.479186        11.427849
# std       4.651092    16.430008        13.398923         7.262919
# min      18.411826  -157.837461         0.000000         0.000000
# 25%      35.769852   -94.202573         7.500000         7.000000
# 50%      40.020710   -81.675414        11.870000        10.990000
# 75%      41.455179   -74.743820        15.950000        14.950000
# max      64.854370   -66.024871       312.950000       118.990000
#
#        priceRangeMin  priceRangeMax
# count    1557.000000    1557.000000
# mean       15.597945      36.566474
# std        18.495854      21.737839
# min         0.000000      12.000000
# 25%         0.000000      30.000000
# 50%        25.000000      40.000000
# 75%        25.000000      40.000000
# max       347.000000     666.000000

# %% [markdown]
# ### manipulation with index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3510, step=1)

# %%
df.set_index('id',inplace=True) #inplace true means modify thee original dataframe

# %%
#by having row indexes now we can use loc function
df.loc['AVwc_6KEIN2L1WUfrKAH']
# Out:
#                                                       address   categories  \
# id
# AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target  Pizza Place
# AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target  Pizza Place
#
#                       city country  \
# id
# AVwc_6KEIN2L1WUfrKAH  Bend      US
# AVwc_6KEIN2L1WUfrKAH  Bend      US
#
#                                                                    keys  \
# id
# AVwc_6KEIN2L1WUfrKAH  us/or/bend/cascadevillagemallacrossfromtarget/...
# AVwc_6KEIN2L1WUfrKAH  us/or/bend/cascadevillagemallacrossfromtarget/...
#
#                        latitude   longitude menuPageURL  menus.amountMax  \
# id
# AVwc_6KEIN2L1WUfrKAH  44.102665 -121.300797         NaN            22.50
# AVwc_6KEIN2L1WUfrKAH  44.102665 -121.300797         NaN            18.95
#
#                       menus.amountMin menus.currency        menus.dateSeen  \
# id
# AVwc_6KEIN2L1WUfrKAH            15.50            USD  2016-03-31T02:19:42Z
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 5     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 6     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 7     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 8     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 9     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 10    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 11    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 12    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# ...

# %% [markdown]
# ### concat

# %%
#if we want to cancat 2 dataframes
#pd.concat([df,df1])

# %% [markdown]
# ### merge

# %%
#pd.merge(df,df1,on="city",how="outer") #how=left,right

# %% [markdown]
# # Missing Values

# %%
#to check if there is any null value
df.isnull()
# Out:
#          id  address  categories   city  country   keys  latitude  longitude  \
# 0     False    False       False  False    False  False     False      False
# 1     False    False       False  False    False  False     False      False
# 2     False    False       False  False    False  False     False      False
# 3     False    False       False  False    False  False     False      False
# 4     False    False       False  False    False  False     False      False
# 5     False    False       False  False    False  False     False      False
# 6     False    False       False  False    False  False     False      False
# 7     False    False       False  False    False  False     False      False
# 8     False    False       False  False    False  False     False      False
# 9     False    False       False  False    False  False     False      False
# 10    False    False       False  False    False  False     False      False
# ...

# %%
print(df.isnull().sum())
# Out:
# id                       0
# address                  0
# categories               0
# city                     0
# country                  0
# keys                     0
# latitude                 0
# longitude                0
# menuPageURL           2900
# menus.amountMax        562
# menus.amountMin        562
# menus.currency         559
# menus.dateSeen           0
# menus.description     1984
# menus.name               0
# name                     0
# postalCode              26
# priceRangeCurrency    1953
# priceRangeMin         1953
# priceRangeMax         1953
# province                 0
# dtype: int64

# %% [markdown]
# ##  Filling Missing Values

# %% [markdown]
# ### 1) if missing values no in large number,we can directly drop them

# %%
# Drop rows with missing values
df.dropna(axis=0).head()
# Out:
#                        id                 address  \
# 227  AVwc-6fkkufWRAb51EsV  10300 Forest Hill Blvd
# 316  AVwce1nRByjofQCxetxl          1495 Union Ave
# 418  AVwcgJpG_7pvs4fzvxFA            1201 16th St
# 423  AVwcgJpG_7pvs4fzvxFA            1201 16th St
# 425  AVwcgJpG_7pvs4fzvxFA            1201 16th St
#
#                                             categories        city country  \
# 227  Pizza Place,Take Out Restaurants,American Rest...  Wellington      US
# 316                     Pizza Place,Italian Restaurant     Memphis      US
# 418  Pizza Place, Bar, and Sports Bar LoDo,American...      Denver      US
# 423  Pizza Place, Bar, and Sports Bar LoDo,American...      Denver      US
# 425  Pizza Place, Bar, and Sports Bar LoDo,American...      Denver      US
#
#                                                   keys   latitude   longitude  \
# 227  us/villageofwellington/wellington/10300foresth...  26.647114  -80.209319
# ...

# %%
# Drop columns with missing values 
df.dropna(axis=1).head()
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %%
df.dropna(how="all").head()  #drop only those rows who have all NaN values
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %%
df.dropna(thresh=2).head()  #atleast 2 Nan
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %% [markdown]
# ### 2) fill them with other values

# %%
df.dtypes
# Out:
# id                     object
# address                object
# categories             object
# city                   object
# country                object
# keys                   object
# latitude              float64
# longitude             float64
# menuPageURL            object
# menus.amountMax       float64
# menus.amountMin       float64
# menus.currency         object
# menus.dateSeen         object
# menus.description      object
# menus.name             object
# name                   object
# postalCode             object
# priceRangeCurrency     object
# priceRangeMin         float64
# priceRangeMax         float64
# province               object
# dtype: object

# %%
#we can fill with anything which we want like mean ,median etc
import numpy as np
mean=np.mean(df.priceRangeMin)
df.priceRangeMin.fillna(mean)
# Out:
# 0       15.597945
# 1       15.597945
# 2       50.000000
# 3       50.000000
# 4       50.000000
# 5       50.000000
# 6       50.000000
# 7       15.597945
# 8       15.597945
# 9       15.597945
# 10      15.597945
# 11      15.597945
# 12      15.597945
# 13      25.000000
# 14      15.597945
# 15      15.597945
# 16      15.597945
# 17      15.597945
# 18      15.597945
# 19      15.597945
# 20       0.000000
# 21      25.000000
# 22      25.000000
# 23      25.000000
# 24      25.000000
# 25      15.597945
# 26      15.597945
# 27      15.597945
# 28      15.597945
# 29      15.597945
#           ...
# 3480     0.000000
# 3481     0.000000
# 3482     0.000000
# 3483     0.000000
# 3484     0.000000
# 3485     0.000000
# 3486    31.000000
# 3487    31.000000
# 3488    15.597945
# 3489    15.597945
# 3490    15.597945
# 3491    15.597945
# 3492     0.000000
# 3493    50.000000
# 3494    25.000000
# 3495    25.000000
# 3496    25.000000
# 3497    25.000000
# 3498    15.597945
# ...

# %%
df.fillna(method="ffill").head() #forward fill ..carry forward the previous value
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %%
#we also have bfill ie backward fill...to fill value of next day
df.fillna(method="bfill").head()
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %% [markdown]
# ####  #limit will control how many times a file must be copied

# %%
df.fillna(method="ffill",limit=1)
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 5     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 6     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 7     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 8     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 9     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 10    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 11    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 12    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# ...

# %%
df.interpolate()  ##we can also give method
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 5     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 6     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 7     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 8     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 9     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 10    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 11    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 12    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# ...

# %% [markdown]
# ### Third way is to replace them

# %%
df.replace([-99999,-88888],np.nan)
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 5     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 6     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 7     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 8     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 9     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 10    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 11    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 12    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# ...

# %%
df.replace({
    -99999:np.nan,
    -88888:np.nan,
    'no available':'default'
})
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 5     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 6     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 7     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 8     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 9     AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 10    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 11    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# 12    AVwc_7d_IN2L1WUfrKNN                      5142 Hollywood Blvd
# ...

# %% [markdown]
# ### replace na  values based on condition

# %%
import numpy as np
np.where(df['address'].str.contains('Cascade'), 1,0)
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %% [markdown]
# # Visualization

# %%
citycount=df['city'].value_counts().head()
citycount.plot(kind='bar',figsize=(20,5))

# %%
##lets see how menus.amountMax is
df['menus.amountMax'].plot(kind='hist',bins=10,figsize=(20,5))

# %% [markdown]
# ### The graph is very difficult to analyse due to skewness,therefore converting values to log

# %%
df['menus.amountMax'].fillna(np.mean(df['menus.amountMax']),inplace=True)

# %%
np.log(df['menus.amountMax']+1).plot(kind='hist',bins=10,figsize=(20,5))

# %%
#lets make groups
labels = ['0-99', '100-199', '200-299']
df['menus.amountMax-group'] =pd.cut(df['menus.amountMax'],range(0,301,100),right=False,labels=labels)

# %%
df.head()
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %%
count=df['menus.amountMax'].value_counts().head()
count.plot(kind='bar',figsize=(20,5))

# %% [markdown]
# ### scatter plot

# %%
plt.scatter(df['latitude'],df['longitude'])
plt.show()

# %% [markdown]
# ## Outliers can be seen in the above scatter plot

# %% [markdown]
# # converting categorical data into numerical

# %%
print(df.dtypes)
df['menus.name'] = df['menus.name'].astype('category')
print("\n after converting to category \n")
print(df.dtypes)
# Out:
# id                         object
# address                    object
# categories                 object
# city                       object
# country                    object
# keys                       object
# latitude                  float64
# longitude                 float64
# menuPageURL                object
# menus.amountMax           float64
# menus.amountMin           float64
# menus.currency             object
# menus.dateSeen             object
# menus.description          object
# menus.name                 object
# name                       object
# postalCode                 object
# priceRangeCurrency         object
# priceRangeMin             float64
# priceRangeMax             float64
# province                   object
# menus.amountMax-group    category
# dtype: object
#
#  after converting to category
#
# id                         object
# address                    object
# categories                 object
# city                       object
# ...

# %%
#Then you can assign the encoded variable to a new column using the cat.codes accessor:
df["menus.name_cat"] = df['menus.name'].cat.codes
df.head()
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %% [markdown]
# # Corelation

# %%
df.corr()
# Out:
#                  latitude  longitude  menus.amountMax  menus.amountMin  \
# latitude         1.000000   0.265316        -0.070553        -0.088359
# longitude        0.265316   1.000000        -0.046164         0.035573
# menus.amountMax -0.070553  -0.046164         1.000000         0.535788
# menus.amountMin -0.088359   0.035573         0.535788         1.000000
# priceRangeMin    0.102451   0.080121         0.049753         0.063362
# priceRangeMax    0.045673   0.036391         0.023326         0.043480
# menus.name_cat   0.026529   0.008525         0.011844        -0.008681
#
#                  priceRangeMin  priceRangeMax  menus.name_cat
# latitude              0.102451       0.045673        0.026529
# longitude             0.080121       0.036391        0.008525
# menus.amountMax       0.049753       0.023326        0.011844
# menus.amountMin       0.063362       0.043480       -0.008681
# priceRangeMin         1.000000       0.818882        0.042080
# ...

# %%
df.corr()['menus.amountMax'].sort_values(ascending=False)
# Out:
# menus.amountMax    1.000000
# menus.amountMin    0.535788
# priceRangeMin      0.049753
# priceRangeMax      0.023326
# menus.name_cat     0.011844
# longitude         -0.046164
# latitude          -0.070553
# Name: menus.amountMax, dtype: float64
